# %%
coherence_acc = [0.11, 0.14, 0.16, 0.17, 0.17, 0.19, 0.17, 0.2, 0.2, 0.18, 0.18, 0.17, 0.17, 0.19, 0.19, 0.18, 0.17, 0.17, 0.17, 0.18, 0.2, 0.16, 0.17, 0.19, 0.2, 0.21, 0.2, 0.2, 0.2, 0.2]

fluency_acc = [0.16, 0.22, 0.15, 0.19, 0.17, 0.19, 0.18, 0.16, 0.16, 0.16, 0.18, 0.17, 0.17, 0.18, 0.18, 0.16, 0.17, 0.17, 0.17, 0.17, 0.2, 0.19, 0.17, 0.15, 0.18, 0.12, 0.17, 0.14, 0.16, 0.18]

consist_acc = [0.29, 0.22, 0.24, 0.14, 0.18, 0.17, 0.18, 0.12, 0.18, 0.14, 0.21, 0.17, 0.15, 0.14, 0.12, 0.13, 0.17, 0.12, 0.13, 0.17, 0.2, 0.1, 0.12, 0.1, 0.1, 0.11, 0.36, 0.1, 0.08, 0.12]

rele_acc = [0.12, 0.11, 0.11, 0.12, 0.12, 0.14, 0.17, 0.19, 0.18, 0.17, 0.17, 0.2, 0.15, 0.2, 0.2, 0.17, 0.18, 0.18, 0.2, 0.18, 0.15, 0.23, 0.2, 0.21, 0.21, 0.18, 0.27, 0.28, 0.23, 0.21]


import pandas as pd

df = pd.DataFrame({
  "coherence_acc" : coherence_acc,
  "fluency_acc" : fluency_acc,
  "consist_acc" : consist_acc,
  "rele_acc" : rele_acc
})

df.T.describe()

import matplotlib.pyplot as plt

# plt.plot(df.T.describe().loc["mean"])
import hvplot
import hvplot.pandas
hvplot.extension('bokeh')

df.hvplot.line()*df.T.describe().loc["mean"].hvplot.line(color="black", width=2)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3b0d3223-808c-43e6-bef9-bfae70954c6e'>
#   <div id="cbc58024-02c2-4672-ae77-5aec29c42d3c" data-root-id="3b0d3223-808c-43e6-bef9-bfae70954c6e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
fluency_70b_acc = [0.32, 0.31, 0.33, 0.31, 0.33, 0.31, 0.33, 0.33, 0.3, 0.33, 0.32, 0.3, 0.35, 0.31, 0.3, 0.29, 0.29, 0.29, 0.34, 0.33, 0.29, 0.31, 0.28, 0.32, 0.33, 0.3, 0.27, 0.32, 0.33, 0.27]

fluency_8b_acc = [0.16, 0.22, 0.15, 0.19, 0.17, 0.19, 0.18, 0.16, 0.16, 0.16, 0.18, 0.17, 0.17, 0.18, 0.18, 0.16, 0.17, 0.17, 0.17, 0.17, 0.2, 0.19, 0.17, 0.15, 0.18, 0.12, 0.17, 0.14, 0.16, 0.18]


import pandas as pd

df = pd.DataFrame({
  "fluency_8b_acc" : fluency_8b_acc,
  "fluency_70b_acc" : fluency_70b_acc,
})

df.T.describe()

import matplotlib.pyplot as plt

# plt.plot(df.T.describe().loc["mean"])
import hvplot
import hvplot.pandas
hvplot.extension('bokeh')

df.hvplot.line()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8f5f684b-5536-45f6-a7fb-7f8508c67267'>
#   <div id="cf8b361d-572c-4cd2-a7bd-33e7c74ea770" data-root-id="8f5f684b-5536-45f6-a7fb-7f8508c67267" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
coh_accuracy_70b = [0.1, 0.09, 0.08, 0.07, 0.1, 0.11, 0.09, 0.1, 0.08, 0.1, 0.09, 0.11, 0.08, 0.12, 0.12, 0.1, 0.08, 0.11, 0.12, 0.1, 0.1, 0.09, 0.11, 0.12, 0.1, 0.12, 0.13, 0.14, 0.11, 0.15]

coh_accuracy_8b = [0.11, 0.14, 0.16, 0.17, 0.17, 0.19, 0.17, 0.2, 0.2, 0.18, 0.18, 0.17, 0.17, 0.19, 0.19, 0.18, 0.17, 0.17, 0.17, 0.18, 0.2, 0.16, 0.17, 0.19, 0.2, 0.21, 0.2, 0.2, 0.2, 0.2]

df_coh_acc = pd.DataFrame({
  "coherence_acc_8b" : coh_accuracy_8b,
  "coherence_acc_70b" : coh_accuracy_70b,
})

df_coh_acc.T.describe()

df_coh_acc.hvplot.line()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
cons_acc_70b = [0.24, 0.28, 0.29, 0.3, 0.32, 0.32, 0.33, 0.32, 0.3, 0.3, 0.26, 0.28, 0.3, 0.29, 0.27, 0.29, 0.28, 0.25, 0.28, 0.25, 0.31, 0.28, 0.3, 0.28, 0.25, 0.27, 0.25, 0.26, 0.27, 0.29]

cons_acc_8b = [0.29, 0.22, 0.24, 0.14, 0.18, 0.17, 0.18, 0.12, 0.18, 0.14, 0.21, 0.17, 0.15, 0.14, 0.12, 0.13, 0.17, 0.12, 0.13, 0.17, 0.2, 0.1, 0.12, 0.1, 0.1, 0.11, 0.36, 0.1, 0.08, 0.12]

df_cons_acc = pd.DataFrame({
  "consistency_acc_8b" : cons_acc_8b,
  "consistency_acc_70b" : cons_acc_70b,
})

df_cons_acc.T.describe()

df_cons_acc.hvplot.line()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
rel_acc_70b = [0.21, 0.28, 0.34, 0.26, 0.33, 0.28, 0.34, 0.35, 0.28, 0.35, 0.26, 0.38, 0.27, 0.31, 0.33, 0.31, 0.33, 0.24, 0.34, 0.31, 0.32, 0.28, 0.29, 0.32, 0.31, 0.28, 0.29, 0.32, 0.32, 0.36]

rel_acc_8b = [0.12, 0.11, 0.11, 0.12, 0.12, 0.14, 0.17, 0.19, 0.18, 0.17, 0.17, 0.2, 0.15, 0.2, 0.2, 0.17, 0.18, 0.18, 0.2, 0.18, 0.15, 0.23, 0.2, 0.21, 0.21, 0.18, 0.27, 0.28, 0.23, 0.21]

df_rel_acc = pd.DataFrame({
  "relevance_acc_8b" : rel_acc_8b,
  "relevance_acc_70b" : rel_acc_70b,
})

df_rel_acc.T.describe()

df_rel_acc.hvplot.line()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
flu_70b_acc = [0.32, 0.31, 0.33, 0.31, 0.33, 0.31, 0.33, 0.33, 0.3, 0.33, 0.32, 0.3, 0.35, 0.31, 0.3, 0.29, 0.29, 0.29, 0.34, 0.33, 0.29, 0.31, 0.28, 0.32, 0.33, 0.3, 0.27, 0.32, 0.33, 0.27]

flu_8b_acc = [0.16, 0.22, 0.15, 0.19, 0.17, 0.19, 0.18, 0.16, 0.16, 0.16, 0.18, 0.17, 0.17, 0.18, 0.18, 0.16, 0.17, 0.17, 0.17, 0.17, 0.2, 0.19, 0.17, 0.15, 0.18, 0.12, 0.17, 0.14, 0.16, 0.18]

coh_acc_70b = [0.1, 0.09, 0.08, 0.07, 0.1, 0.11, 0.09, 0.1, 0.08, 0.1, 0.09, 0.11, 0.08, 0.12, 0.12, 0.1, 0.08, 0.11, 0.12, 0.1, 0.1, 0.09, 0.11, 0.12, 0.1, 0.12, 0.13, 0.14, 0.11, 0.15]

coh_acc_8b = [0.11, 0.14, 0.16, 0.17, 0.17, 0.19, 0.17, 0.2, 0.2, 0.18, 0.18, 0.17, 0.17, 0.19, 0.19, 0.18, 0.17, 0.17, 0.17, 0.18, 0.2, 0.16, 0.17, 0.19, 0.2, 0.21, 0.2, 0.2, 0.2, 0.2]

cons_acc_70b = [0.24, 0.28, 0.29, 0.3, 0.32, 0.32, 0.33, 0.32, 0.3, 0.3, 0.26, 0.28, 0.3, 0.29, 0.27, 0.29, 0.28, 0.25, 0.28, 0.25, 0.31, 0.28, 0.3, 0.28, 0.25, 0.27, 0.25, 0.26, 0.27, 0.29]

cons_acc_8b = [0.29, 0.22, 0.24, 0.14, 0.18, 0.17, 0.18, 0.12, 0.18, 0.14, 0.21, 0.17, 0.15, 0.14, 0.12, 0.13, 0.17, 0.12, 0.13, 0.17, 0.2, 0.1, 0.12, 0.1, 0.1, 0.11, 0.36, 0.1, 0.08, 0.12]

rel_acc_70b = [0.21, 0.28, 0.34, 0.26, 0.33, 0.28, 0.34, 0.35, 0.28, 0.35, 0.26, 0.38, 0.27, 0.31, 0.33, 0.31, 0.33, 0.24, 0.34, 0.31, 0.32, 0.28, 0.29, 0.32, 0.31, 0.28, 0.29, 0.32, 0.32, 0.36]

rel_acc_8b = [0.12, 0.11, 0.11, 0.12, 0.12, 0.14, 0.17, 0.19, 0.18, 0.17, 0.17, 0.2, 0.15, 0.2, 0.2, 0.17, 0.18, 0.18, 0.2, 0.18, 0.15, 0.23, 0.2, 0.21, 0.21, 0.18, 0.27, 0.28, 0.23, 0.21]

df = pd.DataFrame({
  "Fluency 8b" : flu_8b_acc,
  "Fluency 70b" : flu_70b_acc,
  "Coherence 8b" : coh_acc_8b,
  "Coherence 70b" : coh_acc_70b,
  "Consistency 8b" : cons_acc_8b,
  "Consistency 70b" : cons_acc_70b,
  "Relevance 8b" : rel_acc_8b,
  "Relevance 70b" : rel_acc_70b,
})

df["Mean 8b"] = df[["Fluency 8b", "Coherence 8b", "Consistency 8b", "Relevance 8b"]].mean(axis=1)

df["Mean 70b"] = df[["Fluency 70b", "Coherence 70b", "Consistency 70b", "Relevance 70b"]].mean(axis=1)


mean_df = df[["Mean 8b", "Mean 70b"]]

mean_df.T.describe()

mean_df.hvplot.line()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
df = pd.DataFrame({
  "Fluency 8b" : flu_8b_acc,
  "Fluency 70b" : flu_70b_acc,
  "Coherence 8b" : coh_acc_8b,
  "Coherence 70b" : coh_acc_70b,
  "Consistency 8b" : cons_acc_8b,
  "Consistency 70b" : cons_acc_70b,
  "Relevance 8b" : rel_acc_8b,
  "Relevance 70b" : rel_acc_70b,
})

df.T.describe()

df.hvplot.line()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)
